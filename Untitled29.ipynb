# %% [markdown]
# <a href="https://colab.research.google.com/github/hassankotey/viewing-protein-structure/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit
from rdkit import Chem
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 32.1 MB/s eta 0:00:00
# ...

# %%
# to display chemical structures in dataframesimport pandas as pd                                     # importing the pandas library

from rdkit.Chem import PandasTools                      # importing rdkit functions to work with pandas

PandasTools.RenderImagesInAllDataFrames(images=True)

# %%
import pandas as pd

# %%
binding_file = "binding.csv"

binding_df = pd.read_csv(binding_file)

binding_df
# Out:
#      Compounds  Binding Energy
# 0    7745-1519            -8.2
# 1    V019-2634            -7.5
# 2     C226-434            -9.2
# 3    C226-4340            -9.2
# 4    D491-7336            -7.3
# 5    Y020-1313            -9.5
# 6    Y020-1361            -9.4
# 7   Y020-1108             -9.6
# 8    Y020-1362            -9.7
# 9    Y020-1441            -9.2
# 10   F235-0208            -7.6
# 11   F235-0214            -7.7
# 12   Y020-1324            -9.6
# 13  Y020-1126             -9.2
# 14   K607-0578            -8.4
# 15   Y070-0626            -8.1
# 16   Y070-0297            -8.2
# 17   Y070-0848            -7.6
# 18   D481-1714            -8.0
# 19   D351-0588            -7.9
# 20   D481-1716            -7.0
# 21  D351-0606             -7.8
# 22   F113-0052            -9.1
# 23   D344-8428            -9.2
# 24   G917-0162            -7.8

# %%
print(binding_df.columns)
# Out:
# Index(['Compounds', 'Binding Energy'], dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd # Ensure pandas is imported

# print the column names to verify
print(binding_df.columns)

# Replace 'Actual_X_Column_Name' and 'Actual_Y_Column_Name' with your actual column names
# Assuming the columns are named 'Compounds' and 'Binding Energy' based on the traceback and global variables
plt.scatter(binding_df['Compounds'], binding_df['Binding Energy'])
plt.xlabel('Compounds') # Update label for clarity
plt.ylabel('Binding Energy') # Update label for clarity
plt.title('Compound Binding Energy') # Update title for clarity
plt.show()
# Out:
# Index(['Compounds', 'Binding Energy'], dtype='object')

# %%
import matplotlib.pyplot as plt

# Changed the color of the scatter plot points to red
plt.scatter(binding_df['column_for_x'], binding_df['column_for_y'], color='red')
plt.xlabel('Label for X-axis')
plt.ylabel('Label for Y-axis')
plt.title('Your Scatter Plot Title')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_for_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-205a8af02755> in <cell line: 0>()
#       2
#       3 # Changed the color of the scatter plot points to red
# ...

# %%
import matplotlib.pyplot as plt

# Changed the color of the scatter plot points to red
# Replaced placeholder column names with actual column names 'Compounds' and 'Binding Energy'
plt.scatter(binding_df['Compounds'], binding_df['Binding Energy'], color='green')
plt.xlabel('Compounds') # Updated label for clarity
plt.ylabel('Binding Energy') # Updated label for clarity
plt.title('Compound Binding Energy') # Updated title for clarity
plt.show()

# %%
import matplotlib.pyplot as plt

# Changed the plot type from scatter to a line plot (zigzag) and kept the color red
# Replaced placeholder column names with actual column names 'Compounds' and 'Binding Energy'
plt.plot(binding_df['Compounds'], binding_df['Binding Energy'], color='red') # Changed to plt.plot
plt.xlabel('Compounds') # Updated label for clarity
plt.ylabel('Binding Energy') # Updated label for clarity
plt.title('Compound Binding Energy') # Updated title for clarity
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd # Ensure pandas is imported

# print the column names to verify
print(binding_df.columns)

# Scatter plot with color representing binding energy
# Using 'Compounds' for x-axis and 'Binding Energy' for y-axis
# Color of each point is determined by its 'Binding Energy' value using a colormap
plt.scatter(binding_df['Compounds'], binding_df['Binding Energy'], c=binding_df['Binding Energy'], cmap='viridis') # Use 'c' for color and 'cmap' for colormap
plt.xlabel('Compounds') # Update label for clarity
plt.ylabel('Binding Energy') # Update label for clarity
plt.title('Compound Binding Energy with Color Representing Binding Affinity') # Update title for clarity

# Add a colorbar to show the mapping between color and binding energy
plt.colorbar(label='Binding Energy')

plt.show()
# Out:
# Index(['Compounds', 'Binding Energy'], dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Scatter plot with color representing binding energy
plt.scatter(binding_df['Compounds'], binding_df['Binding Energy'], c=binding_df['Binding Energy'], cmap='viridis')
plt.xlabel('Compounds')
plt.ylabel('Binding Energy')
plt.title('Compound Binding Energy with Color Representing Binding Affinity')

# Add a colorbar
plt.colorbar(label='Binding Energy')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90) # Rotate labels by 90 degrees

plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Scatter plot with color representing binding energy
plt.scatter(binding_df['Compounds'], binding_df['Binding Energy'], c=binding_df['Binding Energy'], cmap='viridis')
plt.xlabel('Compounds')
plt.ylabel('Binding Energy')
plt.title('Compound Binding Energy with Color Representing Binding Affinity')

# Add a colorbar
plt.colorbar(label='Binding Energy')

# Rotate x-axis labels for better visibility and make them smaller
plt.xticks(rotation=90, fontsize=8) # Rotate labels by 90 degrees and reduce font size

plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Scatter plot with color representing binding energy
plt.scatter(binding_df['Compounds'], binding_df['Binding Energy'], c=binding_df['Binding Energy'], cmap='viridis')
plt.xlabel('Compounds')
plt.ylabel('Binding Energy')
plt.title('Compound Binding Energy with Color Representing Binding Affinity')

# Add a colorbar
plt.colorbar(label='Binding Energy')

# Rotate x-axis labels for better visibility and make them smaller
plt.xticks(rotation=90, fontsize=8) # Rotate labels by 90 degrees and reduce font size

plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns # Often used for more aesthetically pleasing plots

# Use a seaborn style for better aesthetics
sns.set_style("whitegrid") # You can try different styles like "darkgrid", "white", "ticks"

# Scatter plot with color representing binding energy
# Using a different colormap, adjusting marker size and transparency
plt.figure(figsize=(12, 6)) # Increase figure size for better readability of labels
plt.scatter(binding_df['Compounds'], binding_df['Binding Energy'],
            c=binding_df['Binding Energy'], cmap='plasma', # Changed colormap to 'plasma'
            s=50, alpha=0.8) # Adjusted marker size and added transparency

plt.xlabel('Compounds', fontsize=12) # Increase label font size
plt.ylabel('Binding Energy (arbitrary units)', fontsize=12) # Add units if known, increase font size
plt.title('Binding Energy Profile of Compounds', fontsize=14) # Make title more descriptive, increase font size

# Add a colorbar
cbar = plt.colorbar(label='Binding Energy')
cbar.set_label('Binding Energy', fontsize=12) # Increase colorbar label font size

# Rotate x-axis labels for better visibility and make them smaller
plt.xticks(rotation=90, fontsize=8)

plt.tight_layout() # Adjust layout to prevent labels from being cut off

# Save the figure in a high-resolution format (optional, but good for publications)
# plt.savefig('binding_energy_plot.png', dpi=300, bbox_inches='tight')
# plt.savefig('binding_energy_plot.pdf', bbox_inches='tight')


plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Use a seaborn style for better aesthetics
sns.set_style("whitegrid")

# Sort the DataFrame by 'Binding Energy' to create a ranked plot
binding_df_sorted = binding_df.sort_values(by='Binding Energy', ascending=False) # Sort by binding energy, adjust ascending based on desired order

plt.figure(figsize=(14, 7)) # Increase figure size further for potentially more compounds

# Create a line plot of binding energy, sorted by energy
# Using 'plot' to connect the points in the sorted order
plt.plot(binding_df_sorted['Compounds'], binding_df_sorted['Binding Energy'], marker='o', linestyle='-', color='royalblue', alpha=0.8) # Added markers and linestyle

# Optionally, plot scatter points on top for clarity of individual points
# plt.scatter(binding_df_sorted['Compounds'], binding_df_sorted['Binding Energy'], c=binding_df_sorted['Binding Energy'], cmap='plasma', s=60, alpha=0.9)


plt.xlabel('Compounds (Ranked by Binding Energy)', fontsize=12) # Update label to reflect ranking
plt.ylabel('Binding Energy (arbitrary units)', fontsize=12)
plt.title('Binding Energy Profile of Compounds (Ranked)', fontsize=14)

# Add horizontal lines to indicate key thresholds or the range (optional)
# plt.axhline(y=0, color='grey', linestyle='--', linewidth=0.8) # Example for a zero line

# Rotate x-axis labels for better visibility and make them smaller
plt.xticks(rotation=90, fontsize=8)

plt.tight_layout() # Adjust layout

# Save the figure
# plt.savefig('binding_energy_ranked_plot.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-34cfb772f4b9> in <cell line: 0>()
#       7
#       8 # Sort the DataFrame by 'Binding Energy' to create a ranked plot
# ----> 9 binding_df_sorted = binding_df.sort_values(by='Binding Energy', ascending=False) # Sort by binding energy, adjust ascending based on desired order
#      10
#      11 plt.figure(figsize=(14, 7)) # Increase figure size further for potentially more compounds
#
# NameError: name 'binding_df' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Use a seaborn style for better aesthetics
sns.set_style("whitegrid")

# --- Add the code to load the dataframe ---
# Define the file name
binding_file = "binding.csv"

# Read the CSV file into a pandas DataFrame
binding_df = pd.read_csv(binding_file)
# --- End of added code ---


# Sort the DataFrame by 'Binding Energy' to create a ranked plot
binding_df_sorted = binding_df.sort_values(by='Binding Energy', ascending=False) # Sort by binding energy, adjust ascending based on desired order

plt.figure(figsize=(14, 7)) # Increase figure size further for potentially more compounds

# Create a line plot of binding energy, sorted by energy
# Using 'plot' to connect the points in the sorted order
plt.plot(binding_df_sorted['Compounds'], binding_df_sorted['Binding Energy'], marker='o', linestyle='-', color='royalblue', alpha=0.8) # Added markers and linestyle

# Optionally, plot scatter points on top for clarity of individual points
# plt.scatter(binding_df_sorted['Compounds'], binding_df_sorted['Binding Energy'], c=binding_df_sorted['Binding Energy'], cmap='plasma', s=60, alpha=0.9)


plt.xlabel('Compounds (Ranked by Binding Energy)', fontsize=12) # Update label to reflect ranking
plt.ylabel('Binding Energy (arbitrary units)', fontsize=12)
plt.title('Binding Energy Profile of Compounds (Ranked)', fontsize=14)

# Add horizontal lines to indicate key thresholds or the range (optional)
# plt.axhline(y=0, color='grey', linestyle='--', linewidth=0.8) # Example for a zero line

# Rotate x-axis labels for better visibility and make them smaller
plt.xticks(rotation=90, fontsize=8)

plt.tight_layout() # Adjust layout

# Save the figure
# plt.savefig('binding_energy_ranked_plot.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4e580f86811d> in <cell line: 0>()
#      11
#      12 # Read the CSV file into a pandas DataFrame
# ---> 13 binding_df = pd.read_csv(binding_file)
#      14 # --- End of added code ---
#      15
#
# ...
